# %% [markdown]
# ## **Import Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Install Package**

# %%
# !pip install roboflow
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.0/285.0 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 23.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 74.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 102.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 5.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 5.0.0.93
#     Uninstalling opencv-python-headless-5.0.0.93:
#       Successfully uninstalled opencv-python-headless-5.0.0.93
#   Attempting uninstall: typer
#     Found existing installation: typer 0.26.8
#     Uninstalling typer-0.26.8:
#       Successfully uninstalled typer-0.26.8
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.1/46.1 kB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 23.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# # **Import Package**

# %%
from roboflow import Roboflow
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# Dataset Malam
rf = Roboflow(api_key="5f93vvFjQh7vRbZMQ8sA")
project = rf.workspace("dalam-nama-tuhan-yesus-w134").project("dataset_malam-rwpmd")
version = project.version(2)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# Dataset Siang
rf = Roboflow(api_key="5f93vvFjQh7vRbZMQ8sA")
project = rf.workspace("dalam-nama-tuhan-yesus-w134").project("dataset_siang")
version = project.version(2)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to DATASET_SIANG-2 in yolov11:: 100%|██████████| 8303/8303 [00:03<00:00, 2539.21it/s]

# %%
# Dataset Gabungan
rf = Roboflow(api_key="5f93vvFjQh7vRbZMQ8sA")
project = rf.workspace("dalam-nama-tuhan-yesus-w134").project("gabungan-hpusk")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to GABUNGAN-1 in yolov11:: 100%|██████████| 25375/25375 [00:04<00:00, 5323.29it/s]

# %% [markdown]
# # **Pengembangan Model YOLOv11**

# %%
model = YOLO("yolo11s.pt")
model.info()
# Out:
# ...
# YOLO11s summary: 181 layers, 9,458,752 parameters, 0 gradients, 21.7 GFLOPs
# (181, 9458752, 0, 21.718374400000002)

# %% [markdown]
# **TRAINING DATASET SIANG**

# %%
model = YOLO("yolo11s.pt")

result = model.train(
    data="/content/DATASET_SIANG-2/data.yaml",
    epochs=40,
    batch=16,
    imgsz=640,
    lr0=0.0005,
    workers=2,
    optimizer="AdamW",
    patience=4,
    mosaic=1.0,
    close_mosaic=0,
    mixup=0.2,
    plots=True,

    project="/content/drive/MyDrive/TA134!/Data_Train_Siang",
    name="Training",
)
# Out:
# Ultralytics 8.4.106 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %% [markdown]
# **TESTING DATASET SIANG**

# %%
# load best model hasil training
model = YOLO(
    "/content/drive/MyDrive/TA134!/Data_Train_Siang/Training/weights/best.pt")

# %%
# evaluasi case 1 pada data test siang
results = model.val(
    data="/content/DATASET_SIANG-2/data.yaml",
    split="test",
    imgsz=640,

    project="/content/drive/MyDrive/TA134!/Data_Train_Siang/Case1_Siang_Siang",
    name="Evaluasi_Test_Siang",
)

print("Evaluasi Case 1 selesai dan tersimpan di Google Drive!")
# Out:
# Ultralytics 8.4.106 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11s summary (fused): 101 layers, 9,414,348 parameters, 0 gradients, 21.3 GFLOPs
# WARNING ⚠️ val: Slow image access detected (ping: 0.0±0.0 ms, read: 20.3±7.3 MB/s, size: 45.5 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# val: Scanning /content/DATASET_SIANG-2/test/labels... 260 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 260/260 486.8it/s 0.5s
# val: New cache created: /content/DATASET_SIANG-2/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 17/17 2.4it/s 7.1s
#                    all        260       1980      0.816      0.836      0.872      0.754
#                    bus        157        173      0.931      0.965      0.965      0.883
# ...

# %%
# evaluasi case 3 pada data test malam
results = model.val(
    data="/content/DATASET_MALAM-2/data.yaml",
    split="test",
    imgsz=640,

    project="/content/drive/MyDrive/TA134!/Data_Train_Siang/Case3_Siang_Malam",
    name="Evaluasi_Test_Malam",
)

print("Evaluasi Case 3 selesai dan tersimpan di Google Drive!")
# Out:
# Ultralytics 8.4.106 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# WARNING ⚠️ val: Slow image access detected (ping: 0.0±0.0 ms, read: 25.3±4.6 MB/s, size: 41.6 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# val: Scanning /content/DATASET_MALAM-2/test/labels... 534 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 534/534 561.1it/s 1.0s
# val: New cache created: /content/DATASET_MALAM-2/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 34/34 3.2it/s 10.5s
#                    all        534       1760      0.565      0.582      0.568      0.446
#                    bus        137        146      0.639      0.582      0.682      0.583
#                    car        315        696      0.469      0.723      0.548      0.468
# ...

# %% [markdown]
# **TRAINING DATASET MALAM**

# %%
model = YOLO("yolo11s.pt")

result = model.train(
    data="/content/DATASET_MALAM-2/data.yaml",
    epochs=40,
    batch=16,
    imgsz=640,
    lr0=0.0005,
    workers=2,
    optimizer="AdamW",
    patience=4,
    mosaic=1.0,
    close_mosaic=0,
    mixup=0.2,
    plots=True,

    project="/content/drive/MyDrive/TA134!/Data_Train_Malam",
    name="Training",
)
# Out:
# Ultralytics 8.4.106 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %% [markdown]
# **TESTING DATASET MALAM**

# %%
# load best model hasil training
model = YOLO(
    "/content/drive/MyDrive/TA134!/Data_Train_Malam/Training/weights/best.pt")

# %%
# evaluasi case 2 pada data test malam
results = model.val(
    data="/content/DATASET_MALAM-2/data.yaml",
    split="test",
    imgsz=640,

    project="/content/drive/MyDrive/TA134!/Data_Train_Malam/Case2_Malam_Malam",
    name="Evaluasi_Test_Malam",
)

print("Evaluasi Case 2 selesai dan tersimpan di Google Drive!")
# Out:
# Ultralytics 8.4.106 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11s summary (fused): 101 layers, 9,414,348 parameters, 0 gradients, 21.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1146.1±456.9 MB/s, size: 39.0 KB)
# val: Scanning /content/DATASET_MALAM-2/test/labels.cache... 534 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 534/534 140.0Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 34/34 3.2it/s 10.5s
#                    all        534       1760      0.711      0.847      0.805        0.7
#                    bus        137        146       0.88      0.945      0.958      0.905
#                    car        315        696       0.62      0.789      0.722      0.656
#             motorcycle        294        752       0.57      0.737      0.678      0.499
#                  truck        142        166      0.776      0.919      0.862      0.739
# ...

# %%
# evaluasi case 4 pada data test siang
results = model.val(
    data="/content/DATASET_SIANG-2/data.yaml",
    split="test",
    imgsz=640,

    project="/content/drive/MyDrive/TA134!/Data_Train_Malam/Case2_Malam_Siang",
    name="Evaluasi_Test_Siang",
)

print("Evaluasi Case 4 selesai dan tersimpan di Google Drive!")
# Out:
# Ultralytics 8.4.106 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1584.6±369.6 MB/s, size: 47.3 KB)
# val: Scanning /content/DATASET_SIANG-2/test/labels.cache... 260 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 260/260 99.1Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 17/17 2.6it/s 6.6s
#                    all        260       1980      0.766      0.728      0.794      0.654
#                    bus        157        173      0.844       0.85      0.886      0.794
#                    car        218        747      0.768      0.593      0.744       0.64
#             motorcycle        213        864      0.765      0.726      0.795      0.557
#                  truck        148        196      0.688      0.745      0.753      0.625
# Speed: 2.9ms preprocess, 9.7ms inference, 0.0ms loss, 2.0ms postprocess per image
# ...

# %% [markdown]
# **TRAINING DATASET GABUNGAN**

# %%
model = YOLO("yolo11s.pt")

result = model.train(
    data="/content/GABUNGAN-1/data.yaml",
    epochs=40,
    batch=16,
    imgsz=640,
    lr0=0.0005,
    workers=2,
    optimizer="AdamW",
    patience=4,
    mosaic=1.0,
    close_mosaic=0,
    mixup=0.2,
    plots=True,

    project="/content/drive/MyDrive/TA134!/Data_Train_Gabungan",
    name="Training",
)
# Out:
# Ultralytics 8.4.106 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %% [markdown]
# **TESTING DATASET GABUNGAN**

# %%
model = YOLO(
    "/content/drive/MyDrive/TA134!/Data_Train_Gabungan/Training-2/weights/best.pt")

# %%
# evaluasi case 5 pada data test siang
results = model.val(
    data="/content/DATASET_SIANG-2/data.yaml",
    split="test",
    imgsz=640,

    project="/content/drive/MyDrive/TA134!/Data_Train_Gabungan/Case5_Gabungan_Siang",
    name="Evaluasi_Test_Siang",
)

print("Evaluasi Case 5 selesai dan tersimpan di Google Drive!")
# Out:
# Ultralytics 8.4.106 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11s summary (fused): 101 layers, 9,414,348 parameters, 0 gradients, 21.3 GFLOPs
# WARNING ⚠️ val: Slow image access detected (ping: 0.0±0.0 ms, read: 19.0±8.5 MB/s, size: 49.6 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# val: Scanning /content/DATASET_SIANG-2/test/labels... 260 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 260/260 409.5it/s 0.6s
# val: New cache created: /content/DATASET_SIANG-2/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 17/17 2.1it/s 8.0s
#                    all        260       1980      0.831       0.84      0.886      0.775
#                    bus        157        173      0.959      0.958      0.972      0.902
# ...

# %%
# evaluasi case 6 pada data test malam
results = model.val(
    data="/content/DATASET_MALAM-2/data.yaml",
    split="test",
    imgsz=640,

    project="/content/drive/MyDrive/TA134!/Data_Train_Gabungan/Case6_Gabungan_Malam",
    name="Evaluasi_Test_Malam",
)

print("Evaluasi Case 6 selesai dan tersimpan di Google Drive!")
# Out:
# Ultralytics 8.4.106 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# WARNING ⚠️ val: Slow image access detected (ping: 0.0±0.0 ms, read: 23.4±5.8 MB/s, size: 39.2 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# val: Scanning /content/DATASET_MALAM-2/test/labels... 534 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 534/534 482.7it/s 1.1s
# val: New cache created: /content/DATASET_MALAM-2/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 34/34 3.1it/s 11.0s
#                    all        534       1760      0.731      0.826      0.809      0.707
#                    bus        137        146      0.887      0.986      0.954      0.905
#                    car        315        696      0.669      0.733      0.741      0.676
# ...

# %%
# evaluasi case 7 pada data test gabungan
results = model.val(
    data="/content/GABUNGAN-1/data.yaml",
    split="test",
    imgsz=640,

    project="/content/drive/MyDrive/TA134!/Data_Train_Gabungan/Case7_Gabungan_Gabungan",
    name="Evaluasi_Test_Gabungan",
)

print("Evaluasi Case 7 selesai dan tersimpan di Google Drive!")
# Out:
# Ultralytics 8.4.106 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# WARNING ⚠️ val: Slow image access detected (ping: 0.0±0.0 ms, read: 18.1±6.3 MB/s, size: 42.4 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# val: Scanning /content/GABUNGAN-1/test/labels... 792 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 792/792 505.3it/s 1.6s
# val: New cache created: /content/GABUNGAN-1/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 50/50 3.4it/s 14.9s
#                    all        792       3883      0.781      0.837      0.848       0.74
#                    bus        301        328      0.927       0.97      0.968      0.902
#                    car        540       1503      0.718      0.747      0.776      0.705
# ...
